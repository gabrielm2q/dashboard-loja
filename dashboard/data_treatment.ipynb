# %%
import pandas as pd
import numpy as np
import random
import os

DATASETS_PATH = os.path.normpath("dataset/retail_bi")

# %% [markdown]
# #### Fixing Campanha Dataset

# %%
campanha_df = pd.read_csv(os.path.join(DATASETS_PATH, "Campanha.csv"), sep=",")
display(campanha_df)

# %%
for idx, row in campanha_df.iterrows():
    campanha_df.loc[idx, "lojaId"] = random.randint(1, 5)

display(campanha_df)

# %%
campanha_df.to_csv(os.path.join(DATASETS_PATH, "Campanha.csv"), sep=",", index=False)
